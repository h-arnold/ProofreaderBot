# %% [markdown]
# ## Notebook template
# Run `%run _shared/setup_data_overview.py` in cell 1 to install the documented dependencies, discover the repo root, and load the cleansed dataframes. The helper exposes `issues` and `files`, prints environment versions, and reports shape information so the rest of this notebook can assume the data is ready.
# After the helper runs, keep each subsequent cell focused on new analysis; rely on `issues`/`files` rather than reloading on your own.

# %%
# Shared setup
# %run _shared/setup_data_overview.py
# Out:
# Python: 3.12.11 (main, Jul  1 2025, 05:29:09) [GCC 12.2.0]
# Pandas: 2.3.3
# Plotly: 6.5.0
# Repo root: /workspaces/WjecDocumentScraper
# Data dir: /workspaces/WjecDocumentScraper/notebooks/cleansed_data
# Loaded issues: (24771, 11) files: (239, 3)

# %%
# Quick sanity checks
issues.shape, files.shape
# Out:
# ((24771, 11), (239, 3))
