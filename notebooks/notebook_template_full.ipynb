# %% [markdown]
# # Notebook template — full imports & helpers
#
# Run the setup cell below to load the repository's shared dataframes (`issues` and `files`) and the notebook helper utilities.
#
# Use this template as the starting cell for any data-exploration notebook.

# %%
# Shared setup (loads `issues`, `files` and environment info)
# %run _shared/setup_data_overview.py

# Standard imports for analysis notebooks
import pandas as pd
import numpy as np
from IPython.display import display, Markdown, HTML
import textwrap
import random

# Display config
pd.set_option('display.max_columns', 80)
pd.set_option('display.width', 240)

# Notebook helpers (sampling & display utilities)
# %run _shared/notebook_helpers.py

print("Template loaded: standard imports, display settings and notebook helpers are available.")

# %%
# Quick checks
print(f"issues: {getattr('issues', 'shape', None) or issues.shape}")
print(f"files: {files.shape}")

# Example usage of helpers (uncomment to run)
# sample = sample_factual_issues(issues, n=5)
# display_issues_table(sample)
